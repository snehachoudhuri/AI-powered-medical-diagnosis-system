# %%
#Sneha Choudhuri
import sklearn
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import StandardScaler

# %%
alz_data = pd.read_csv('./Datasets/alzheimers_disease_data.csv')

# %%
alz_data.head()
# Out:
#    Age  Gender        BMI  Smoking  AlcoholConsumption  PhysicalActivity  \
# 0   73       0  22.927749        0           13.297218          6.327112
# 1   89       0  26.827681        0            4.542524          7.619885
# 2   73       0  17.795882        0           19.555085          7.844988
# 3   74       1  33.800817        1           12.209266          8.428001
# 4   89       0  20.716974        0           18.454356          6.310461
#
#    DietQuality  SleepQuality  FamilyHistoryAlzheimers  CardiovascularDisease  \
# 0     1.347214      9.025679                        0                      0
# 1     0.518767      7.151293                        0                      0
# 2     1.826335      9.673574                        1                      0
# 3     7.435604      8.392554                        0                      0
# 4     0.795498      5.597238                        0                      0
#
# ...

# %%
alz_data.tail()
# Out:
#       Age  Gender        BMI  Smoking  AlcoholConsumption  PhysicalActivity  \
# 2144   61       0  39.121757        0            1.561126          4.049964
# 2145   75       0  17.857903        0           18.767261          1.360667
# 2146   77       0  15.476479        0            4.594670          9.886002
# 2147   78       1  15.299911        0            8.674505          6.354282
# 2148   72       0  33.289738        0            7.890703          6.570993
#
#       DietQuality  SleepQuality  FamilyHistoryAlzheimers  \
# 2144     6.555306      7.535540                        0
# 2145     2.904662      8.555256                        0
# 2146     8.120025      5.769464                        0
# 2147     1.263427      8.322874                        0
# 2148     7.941404      9.878711                        0
#
#       CardiovascularDisease  ...  FunctionalAssessment  MemoryComplaints  \
# 2144                      0  ...              0.238667                 0
# ...

# %%
alz_data.shape
# Out:
# (2149, 28)

# %%
alz_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2149 entries, 0 to 2148
# Data columns (total 28 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Age                        2149 non-null   int64
#  1   Gender                     2149 non-null   int64
#  2   BMI                        2149 non-null   float64
#  3   Smoking                    2149 non-null   int64
#  4   AlcoholConsumption         2149 non-null   float64
#  5   PhysicalActivity           2149 non-null   float64
#  6   DietQuality                2149 non-null   float64
#  7   SleepQuality               2149 non-null   float64
#  8   FamilyHistoryAlzheimers    2149 non-null   int64
#  9   CardiovascularDisease      2149 non-null   int64
#  10  Diabetes                   2149 non-null   int64
#  11  Depression                 2149 non-null   int64
#  12  HeadInjury                 2149 non-null   int64
# ...

# %%
alz_data.isnull().sum()
# Out:
# Age                          0
# Gender                       0
# BMI                          0
# Smoking                      0
# AlcoholConsumption           0
# PhysicalActivity             0
# DietQuality                  0
# SleepQuality                 0
# FamilyHistoryAlzheimers      0
# CardiovascularDisease        0
# Diabetes                     0
# Depression                   0
# HeadInjury                   0
# Hypertension                 0
# SystolicBP                   0
# DiastolicBP                  0
# CholesterolTotal             0
# MMSE                         0
# FunctionalAssessment         0
# MemoryComplaints             0
# BehavioralProblems           0
# ADL                          0
# Confusion                    0
# Disorientation               0
# PersonalityChanges           0
# DifficultyCompletingTasks    0
# Forgetfulness                0
# Diagnosis                    0
# dtype: int64

# %%
alz_data.describe()
# Out:
#                Age       Gender          BMI      Smoking  AlcoholConsumption  \
# count  2149.000000  2149.000000  2149.000000  2149.000000         2149.000000
# mean     74.908795     0.506282    27.655697     0.288506           10.039442
# std       8.990221     0.500077     7.217438     0.453173            5.757910
# min      60.000000     0.000000    15.008851     0.000000            0.002003
# 25%      67.000000     0.000000    21.611408     0.000000            5.139810
# 50%      75.000000     1.000000    27.823924     0.000000            9.934412
# 75%      83.000000     1.000000    33.869778     1.000000           15.157931
# max      90.000000     1.000000    39.992767     1.000000           19.989293
#
#        PhysicalActivity  DietQuality  SleepQuality  FamilyHistoryAlzheimers  \
# count       2149.000000  2149.000000   2149.000000              2149.000000
# mean           4.920202     4.993138      7.051081                 0.252210
# ...

# %%
alz_data['Diagnosis'].value_counts()
# Out:
# Diagnosis
# 0    1389
# 1     760
# Name: count, dtype: int64

# %%
X = alz_data.drop(columns='Diagnosis', axis=1)
Y = alz_data['Diagnosis']

# %%
X
# Out:
#       Age  Gender        BMI  Smoking  AlcoholConsumption  PhysicalActivity  \
# 0      73       0  22.927749        0           13.297218          6.327112
# 1      89       0  26.827681        0            4.542524          7.619885
# 2      73       0  17.795882        0           19.555085          7.844988
# 3      74       1  33.800817        1           12.209266          8.428001
# 4      89       0  20.716974        0           18.454356          6.310461
# ...   ...     ...        ...      ...                 ...               ...
# 2144   61       0  39.121757        0            1.561126          4.049964
# 2145   75       0  17.857903        0           18.767261          1.360667
# 2146   77       0  15.476479        0            4.594670          9.886002
# 2147   78       1  15.299911        0            8.674505          6.354282
# 2148   72       0  33.289738        0            7.890703          6.570993
#
# ...

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2149 entries, 0 to 2148
# Data columns (total 27 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Age                        2149 non-null   int64
#  1   Gender                     2149 non-null   int64
#  2   BMI                        2149 non-null   float64
#  3   Smoking                    2149 non-null   int64
#  4   AlcoholConsumption         2149 non-null   float64
#  5   PhysicalActivity           2149 non-null   float64
#  6   DietQuality                2149 non-null   float64
#  7   SleepQuality               2149 non-null   float64
#  8   FamilyHistoryAlzheimers    2149 non-null   int64
#  9   CardiovascularDisease      2149 non-null   int64
#  10  Diabetes                   2149 non-null   int64
#  11  Depression                 2149 non-null   int64
#  12  HeadInjury                 2149 non-null   int64
# ...

# %%
Y
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 2144    1
# 2145    1
# 2146    1
# 2147    1
# 2148    0
# Name: Diagnosis, Length: 2149, dtype: int64

# %%
scaler = StandardScaler()
scaler.fit(X)
standardized_data = scaler.transform(X)
standardized_data
X = standardized_data
Y = alz_data['Diagnosis']
X
Y
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 2144    1
# 2145    1
# 2146    1
# 2147    1
# 2148    0
# Name: Diagnosis, Length: 2149, dtype: int64

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, stratify=Y, random_state=2)
print(X.shape, X_train.shape, X_test.shape)
# Out:
# (2149, 27) (1719, 27) (430, 27)

# %%
model = LogisticRegression(max_iter=3000)
# training the LogisticRegression model with Training data
model.fit(X_train, Y_train)
#LogisticRegression(max_iter=2000)
# Out:
# LogisticRegression(max_iter=3000)

# %%
# accuracy on training data
X_train_prediction = model.predict(X_train)
training_data_accuracy = accuracy_score(X_train_prediction, Y_train)
print('Accuracy on Training data : ', training_data_accuracy)
# accuracy on test data
X_test_prediction = model.predict(X_test)
test_data_accuracy = accuracy_score(X_test_prediction, Y_test)
print('Accuracy on Test data : ', test_data_accuracy)
# Out:
# Accuracy on Training data :  0.8458406050029087
# Accuracy on Test data :  0.8465116279069768

# %%
input_data = (102,1,22.8265,1,3.54,5.023,7.1,1.837,0,0,1,0,1,1,100,70,200,21,5,1,0,5,1,1,0,0,1)

# change the input data to a numpy array
input_data_as_numpy_array= np.asarray(input_data)
print(input_data_as_numpy_array.dtype)

# reshape the numpy array as we are predicting for only on instance
input_data_reshaped = input_data_as_numpy_array.reshape(1,-1)
print(input_data_reshaped.dtype)

prediction = model.predict(input_data_reshaped)
print(prediction)

if (prediction[0]== 0):
  print('You have Alzheimers. We recommend you visiting a Doctor soon.')
else:
  print('You do not have Alzheimers!')
# Out:
# float64
# float64
# [0]
# You have Alzheimers. We recommend you visiting a Doctor soon.

# %%
import pickle
filename = 'alzheimer_model.sav'
pickle.dump(model, open(filename, 'wb'))
# loading the saved model
loaded_model = pickle.load(open('alzheimer_model.sav', 'rb'))
#for column in X_train.columns:
 # print(column)

# %%
print(sklearn.__version__)
# Out:
# 1.5.1
