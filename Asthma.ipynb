# %%
#Sneha Choudhuri
import sklearn
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import StandardScaler

# %%
Asthma_data = pd.read_csv('./Datasets/asthma.csv')
Asthma_data.head()
# Out:
#    Age  Gender        BMI  Smoking  PhysicalActivity  DietQuality  \
# 0   63       0  15.848744        0          0.894448     5.488696
# 1   26       1  22.757042        0          5.897329     6.341014
# 2   57       0  18.395396        0          6.739367     9.196237
# 3   40       1  38.515278        0          1.404503     5.826532
# 4   61       0  19.283802        0          4.604493     3.127048
#
#    SleepQuality  PollutionExposure  PollenExposure  DustExposure  ...  \
# 0      8.701003           7.388481        2.855578      0.974339  ...
# 1      5.153966           1.969838        7.457665      6.584631  ...
# 2      6.840647           1.460593        1.448189      5.445799  ...
# 3      4.253036           0.581905        7.571845      3.965316  ...
# 4      9.625799           0.980875        3.049807      8.260605  ...
#
#    GastroesophagealReflux  LungFunctionFEV1  LungFunctionFVC  Wheezing  \
# 0                       0          1.369051         4.941206         0
# ...

# %%
Asthma_data.tail()
# Out:
#       Age  Gender        BMI  Smoking  PhysicalActivity  DietQuality  \
# 2387   43       1  29.059613        0          3.019854     6.119637
# 2388   18       1  20.740850        0          5.805180     4.386992
# 2389   54       0  37.079560        0          4.735169     8.214064
# 2390   46       1  23.444712        0          9.672637     7.362861
# 2391   26       1  28.123021        1          1.613138     7.412878
#
#       SleepQuality  PollutionExposure  PollenExposure  DustExposure  ...  \
# 2387      8.300960           2.483829        7.314582      3.425445  ...
# 2388      7.731192           7.733983        2.279073      6.467701  ...
# 2389      7.483521           2.794847        3.055139      9.484013  ...
# 2390      6.717272           9.448862        7.712584      5.051405  ...
# 2391      8.512253           3.231709        3.874028      5.064317  ...
#
#       GastroesophagealReflux  LungFunctionFEV1  LungFunctionFVC  Wheezing  \
# ...

# %%
Asthma_data.shape
# Out:
# (2392, 25)

# %%
Asthma_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2392 entries, 0 to 2391
# Data columns (total 25 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Age                     2392 non-null   int64
#  1   Gender                  2392 non-null   int64
#  2   BMI                     2392 non-null   float64
#  3   Smoking                 2392 non-null   int64
#  4   PhysicalActivity        2392 non-null   float64
#  5   DietQuality             2392 non-null   float64
#  6   SleepQuality            2392 non-null   float64
#  7   PollutionExposure       2392 non-null   float64
#  8   PollenExposure          2392 non-null   float64
#  9   DustExposure            2392 non-null   float64
#  10  PetAllergy              2392 non-null   int64
#  11  FamilyHistoryAsthma     2392 non-null   int64
#  12  HistoryOfAllergies      2392 non-null   int64
#  13  Eczema                  2392 non-null   int64
# ...

# %%
Asthma_data.isnull().sum()
# Out:
# Age                       0
# Gender                    0
# BMI                       0
# Smoking                   0
# PhysicalActivity          0
# DietQuality               0
# SleepQuality              0
# PollutionExposure         0
# PollenExposure            0
# DustExposure              0
# PetAllergy                0
# FamilyHistoryAsthma       0
# HistoryOfAllergies        0
# Eczema                    0
# HayFever                  0
# GastroesophagealReflux    0
# LungFunctionFEV1          0
# LungFunctionFVC           0
# Wheezing                  0
# ShortnessOfBreath         0
# ChestTightness            0
# Coughing                  0
# NighttimeSymptoms         0
# ExerciseInduced           0
# Diagnosis                 0
# dtype: int64

# %%
Asthma_data.describe()
# Out:
#                Age       Gender          BMI      Smoking  PhysicalActivity  \
# count  2392.000000  2392.000000  2392.000000  2392.000000       2392.000000
# mean     42.137960     0.493311    27.244877     0.141722          5.051786
# std      21.606655     0.500060     7.201628     0.348838          2.903574
# min       5.000000     0.000000    15.031803     0.000000          0.001740
# 25%      23.000000     0.000000    20.968313     0.000000          2.578333
# 50%      42.000000     0.000000    27.052202     0.000000          5.016881
# 75%      61.000000     1.000000    33.555903     0.000000          7.540234
# max      79.000000     1.000000    39.985611     1.000000          9.995809
#
#        DietQuality  SleepQuality  PollutionExposure  PollenExposure  \
# count  2392.000000   2392.000000        2392.000000     2392.000000
# mean      5.022867      7.019012           5.013030        5.114221
# std       2.909980      1.732475           2.935605        2.893088
# ...

# %%
Asthma_data['Diagnosis'].value_counts()
# Out:
# Diagnosis
# 0    2268
# 1     124
# Name: count, dtype: int64

# %%
X = Asthma_data.drop(columns='Diagnosis', axis=1)
Y = Asthma_data['Diagnosis']

# %%
X
# Out:
#       Age  Gender        BMI  Smoking  PhysicalActivity  DietQuality  \
# 0      63       0  15.848744        0          0.894448     5.488696
# 1      26       1  22.757042        0          5.897329     6.341014
# 2      57       0  18.395396        0          6.739367     9.196237
# 3      40       1  38.515278        0          1.404503     5.826532
# 4      61       0  19.283802        0          4.604493     3.127048
# ...   ...     ...        ...      ...               ...          ...
# 2387   43       1  29.059613        0          3.019854     6.119637
# 2388   18       1  20.740850        0          5.805180     4.386992
# 2389   54       0  37.079560        0          4.735169     8.214064
# 2390   46       1  23.444712        0          9.672637     7.362861
# 2391   26       1  28.123021        1          1.613138     7.412878
#
#       SleepQuality  PollutionExposure  PollenExposure  DustExposure  ...  \
# ...

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2392 entries, 0 to 2391
# Data columns (total 24 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Age                     2392 non-null   int64
#  1   Gender                  2392 non-null   int64
#  2   BMI                     2392 non-null   float64
#  3   Smoking                 2392 non-null   int64
#  4   PhysicalActivity        2392 non-null   float64
#  5   DietQuality             2392 non-null   float64
#  6   SleepQuality            2392 non-null   float64
#  7   PollutionExposure       2392 non-null   float64
#  8   PollenExposure          2392 non-null   float64
#  9   DustExposure            2392 non-null   float64
#  10  PetAllergy              2392 non-null   int64
#  11  FamilyHistoryAsthma     2392 non-null   int64
#  12  HistoryOfAllergies      2392 non-null   int64
#  13  Eczema                  2392 non-null   int64
# ...

# %%
Y
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 2387    1
# 2388    1
# 2389    1
# 2390    0
# 2391    0
# Name: Diagnosis, Length: 2392, dtype: int64

# %%
scaler = StandardScaler()
scaler.fit(X)
standardized_data = scaler.transform(X)
standardized_data
X = standardized_data
Y = Asthma_data['Diagnosis']
X
Y
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 2387    1
# 2388    1
# 2389    1
# 2390    0
# 2391    0
# Name: Diagnosis, Length: 2392, dtype: int64

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, stratify=Y, random_state=2)
print(X.shape, X_train.shape, X_test.shape)
# Out:
# (2392, 24) (1913, 24) (479, 24)

# %%
model = LogisticRegression(max_iter=3000)
# training the LogisticRegression model with Training data
model.fit(X_train, Y_train)
#LogisticRegression(max_iter=2000)
# Out:
# LogisticRegression(max_iter=3000)

# %%
# accuracy on training data
X_train_prediction = model.predict(X_train)
training_data_accuracy = accuracy_score(X_train_prediction, Y_train)
print('Accuracy on Training data : ', training_data_accuracy)
# accuracy on test data
X_test_prediction = model.predict(X_test)
test_data_accuracy = accuracy_score(X_test_prediction, Y_test)
print('Accuracy on Test data : ', test_data_accuracy)
# Out:
# Accuracy on Training data :  0.9482488238369053
# Accuracy on Test data :  0.9478079331941545

# %%
input_data = (50,1,27.89,1,12.25,1.34,9.93,6.36,67.45,34.92,1,1,0,1,0,1,2.4863,1.3487812,1,1,1,0,0,1)

# change the input data to a numpy array
input_data_as_numpy_array= np.asarray(input_data)
print(input_data_as_numpy_array.dtype)

# reshape the numpy array as we are predicting for only on instance
input_data_reshaped = input_data_as_numpy_array.reshape(1,-1)
print(input_data_reshaped.dtype)

prediction = model.predict(input_data_reshaped)
print(prediction)

if (prediction[0]== 0):
  print('You do not have Asthma.')
else:
  print('You show signs of Asthma. We recommend you visiting a Doctor soon.')
# Out:
# float64
# float64
# [1]
# You show signs of Asthma. We recommend you visiting a Doctor soon.

# %%
import pickle
filename = 'Asthma_model.sav'
pickle.dump(model, open(filename, 'wb'))
# loading the saved model
loaded_model = pickle.load(open('Asthma_model.sav', 'rb'))
#for column in X.columns:
  #print(column)

# %%
print(sklearn.__version__)
# Out:
# 1.5.1
