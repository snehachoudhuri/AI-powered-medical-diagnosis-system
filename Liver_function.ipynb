# %%
import sklearn
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import StandardScaler

# %%
Liver_disease_data = pd.read_csv('./Datasets/Liver_disease_data.csv')
Liver_disease_data.head()
# Out:
#    Age  Gender        BMI  AlcoholConsumption  Smoking  GeneticRisk  \
# 0   58       0  35.857584           17.272828        0            1
# 1   71       1  30.732470            2.201266        0            1
# 2   48       0  19.971407           18.500944        0            0
# 3   34       1  16.615417           12.632870        0            0
# 4   62       1  16.065830            1.087815        0            1
#
#    PhysicalActivity  Diabetes  Hypertension  LiverFunctionTest  Diagnosis
# 0          0.658940         0             0          42.734240          1
# 1          1.670557         1             0          67.309822          1
# 2          9.928308         0             0          63.738956          0
# 3          5.630129         0             0          64.555873          1
# 4          3.566218         1             0          77.868689          1

# %%
Liver_disease_data.tail()
# Out:
#       Age  Gender        BMI  AlcoholConsumption  Smoking  GeneticRisk  \
# 1695   42       0  38.498295           14.384688        0            1
# 1696   40       0  27.600094            5.431009        0            0
# 1697   38       0  38.730017            6.324302        1            2
# 1698   67       0  35.820798           16.899417        0            2
# 1699   80       0  24.060783            9.526447        0            0
#
#       PhysicalActivity  Diabetes  Hypertension  LiverFunctionTest  Diagnosis
# 1695          0.992289         0             0          97.933961          1
# 1696          8.390492         0             0          70.260528          1
# 1697          9.314222         0             1          56.053370          1
# 1698          3.224453         0             0          26.300875          1
# 1699          9.261426         0             1          73.572893          1

# %%
Liver_disease_data.shape
# Out:
# (1700, 11)

# %%
Liver_disease_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1700 entries, 0 to 1699
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Age                 1700 non-null   int64
#  1   Gender              1700 non-null   int64
#  2   BMI                 1700 non-null   float64
#  3   AlcoholConsumption  1700 non-null   float64
#  4   Smoking             1700 non-null   int64
#  5   GeneticRisk         1700 non-null   int64
#  6   PhysicalActivity    1700 non-null   float64
#  7   Diabetes            1700 non-null   int64
#  8   Hypertension        1700 non-null   int64
#  9   LiverFunctionTest   1700 non-null   float64
#  10  Diagnosis           1700 non-null   int64
# dtypes: float64(4), int64(7)
# memory usage: 146.2 KB

# %%
Liver_disease_data.isnull().sum()
# Out:
# Age                   0
# Gender                0
# BMI                   0
# AlcoholConsumption    0
# Smoking               0
# GeneticRisk           0
# PhysicalActivity      0
# Diabetes              0
# Hypertension          0
# LiverFunctionTest     0
# Diagnosis             0
# dtype: int64

# %%
Liver_disease_data.describe()
# Out:
#                Age       Gender          BMI  AlcoholConsumption      Smoking  \
# count  1700.000000  1700.000000  1700.000000         1700.000000  1700.000000
# mean     50.394118     0.504118    27.699801            9.832309     0.291765
# std      17.641915     0.500130     7.210400            5.757472     0.454708
# min      20.000000     0.000000    15.004710            0.003731     0.000000
# 25%      35.000000     0.000000    21.455414            4.841811     0.000000
# 50%      51.000000     1.000000    27.925367            9.828195     0.000000
# 75%      66.000000     1.000000    33.957668           14.871671     1.000000
# max      80.000000     1.000000    39.992845           19.952456     1.000000
#
#        GeneticRisk  PhysicalActivity     Diabetes  Hypertension  \
# count  1700.000000       1700.000000  1700.000000   1700.000000
# mean      0.521765          5.000993     0.142353      0.154706
# std       0.666262          2.847074     0.349515      0.361730
# ...

# %%
Liver_disease_data['Diagnosis'].value_counts()
# Out:
# Diagnosis
# 1    936
# 0    764
# Name: count, dtype: int64

# %%
X = Liver_disease_data.drop(columns='Diagnosis', axis=1)
Y = Liver_disease_data['Diagnosis']

# %%
X
# Out:
#       Age  Gender        BMI  AlcoholConsumption  Smoking  GeneticRisk  \
# 0      58       0  35.857584           17.272828        0            1
# 1      71       1  30.732470            2.201266        0            1
# 2      48       0  19.971407           18.500944        0            0
# 3      34       1  16.615417           12.632870        0            0
# 4      62       1  16.065830            1.087815        0            1
# ...   ...     ...        ...                 ...      ...          ...
# 1695   42       0  38.498295           14.384688        0            1
# 1696   40       0  27.600094            5.431009        0            0
# 1697   38       0  38.730017            6.324302        1            2
# 1698   67       0  35.820798           16.899417        0            2
# 1699   80       0  24.060783            9.526447        0            0
#
#       PhysicalActivity  Diabetes  Hypertension  LiverFunctionTest
# ...

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1700 entries, 0 to 1699
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Age                 1700 non-null   int64
#  1   Gender              1700 non-null   int64
#  2   BMI                 1700 non-null   float64
#  3   AlcoholConsumption  1700 non-null   float64
#  4   Smoking             1700 non-null   int64
#  5   GeneticRisk         1700 non-null   int64
#  6   PhysicalActivity    1700 non-null   float64
#  7   Diabetes            1700 non-null   int64
#  8   Hypertension        1700 non-null   int64
#  9   LiverFunctionTest   1700 non-null   float64
# dtypes: float64(4), int64(6)
# memory usage: 132.9 KB

# %%
Y
# Out:
# 0       1
# 1       1
# 2       0
# 3       1
# 4       1
#        ..
# 1695    1
# 1696    1
# 1697    1
# 1698    1
# 1699    1
# Name: Diagnosis, Length: 1700, dtype: int64

# %%
scaler = StandardScaler()
scaler.fit(X)
standardized_data = scaler.transform(X)
standardized_data
X = standardized_data
Y = Liver_disease_data['Diagnosis']
X
Y
# Out:
# 0       1
# 1       1
# 2       0
# 3       1
# 4       1
#        ..
# 1695    1
# 1696    1
# 1697    1
# 1698    1
# 1699    1
# Name: Diagnosis, Length: 1700, dtype: int64

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, stratify=Y, random_state=2)
print(X.shape, X_train.shape, X_test.shape)
# Out:
# (1700, 10) (1360, 10) (340, 10)

# %%
model = LogisticRegression(max_iter=2000)
# training the LogisticRegression model with Training data
model.fit(X_train, Y_train)
#LogisticRegression(max_iter=2000)
# Out:
# LogisticRegression(max_iter=2000)

# %%
# accuracy on training data
X_train_prediction = model.predict(X_train)
training_data_accuracy = accuracy_score(X_train_prediction, Y_train)
print('Accuracy on Training data : ', training_data_accuracy)
# accuracy on test data
X_test_prediction = model.predict(X_test)
test_data_accuracy = accuracy_score(X_test_prediction, Y_test)
print('Accuracy on Test data : ', test_data_accuracy)
# Out:
# Accuracy on Training data :  0.8352941176470589
# Accuracy on Test data :  0.8382352941176471

# %%
input_data = (70,0,27.894509,12.256380,0,2,1.3421805,1,1,97.933961)

# change the input data to a numpy array
input_data_as_numpy_array= np.asarray(input_data)
print(input_data_as_numpy_array.dtype)

# reshape the numpy array as we are predicting for only on instance
input_data_reshaped = input_data_as_numpy_array.reshape(1,-1)
print(input_data_reshaped.dtype)

prediction = model.predict(input_data_reshaped)
print(prediction)

if (prediction[0]== 0):
  print('You do not have any liver problem.')
else:
  print('Your liver does not function properly. We recommend you visiting a Doctor soon.')
# Out:
# float64
# float64
# [1]
# Your liver does not function properly. We recommend you visiting a Doctor soon.

# %%
import pickle
filename = 'Liver_disease_model.sav'
pickle.dump(model, open(filename, 'wb'))
# loading the saved model
loaded_model = pickle.load(open('Liver_disease_model.sav', 'rb'))
#for column in X.columns:
  #print(column)

# %%
print(sklearn.__version__)
# Out:
# 1.5.1
